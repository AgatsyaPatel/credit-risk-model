# %%
import pandas as pd    # tables and data manipulation
import numpy as np     # math and numbers
import os              # file and folder navigation

# %%
print("Current folder:", os.getcwd())
print("All files here:", os.listdir())
# Out:
# Current folder: c:\Users\imagatsya\Downloads\credit-risk\credit-risk-model\.ipynb_checkpoints
# All files here: ['01_data_loading.ipynb']

# %%
print("Current working directory:", os.getcwd())
print("Files in current folder:", os.listdir())
# Out:
# Current working directory: c:\Users\imagatsya\Downloads\credit-risk\credit-risk-model\.ipynb_checkpoints
# Files in current folder: ['01_data_loading.ipynb']

# %%
os.chdir(r"C:\Users\imagatsya\Downloads\credit-risk\credit-risk-model")

print("FIXED WORKING DIR:", os.getcwd())
# Out:
# FIXED WORKING DIR: C:\Users\imagatsya\Downloads\credit-risk\credit-risk-model

# %%
print(os.listdir())
print(os.listdir("data"))
# Out:
# ['.git', '.gitignore', '.ipynb_checkpoints', 'data', 'README.md', 'src']
# ['accepted_2007_to_2018Q4.csv']

# %%
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df = pd.read_csv("data/accepted_2007_to_2018Q4.csv")
#       2 print(df.shape)
#
# File c:\Users\imagatsya\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
print("CURRENT FOLDER:", os.getcwd())
print("FILES HERE:", os.listdir())
# Out:
# CURRENT FOLDER: c:\Users\imagatsya\Downloads\credit-risk\credit-risk-model\.ipynb_checkpoints
# FILES HERE: ['01_data_loading.ipynb']

# %%
print(os.listdir("data"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(os.listdir("data"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data'

# %%
print(os.listdir("data"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(os.listdir("data"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data'

# %%
columns_we_need = [

    'annual_inc',             
    'emp_length',              
    'home_ownership',          
    'verification_status',    

    # --- LOAN CHARACTERISTICS ---
    # What are the terms of this loan?
    'loan_amnt',               
    'term',                   
    'int_rate',               
    'installment',             
    'grade',                   
    'purpose',                

    # --- CREDIT HISTORY ---
    # What has this person done in the past?
    'fico_range_low',          
    'dti',                     # debt to income — already stretched thin?
    'delinq_2yrs',             
    'mths_since_last_delinq',  # how long ago — recent = still risky
    'pub_rec',                 # bankruptcies — major red flag
    'revol_util',              
    'open_acc',               
    'total_acc',               # length of credit history
    'revol_bal',               # outstanding revolving debt
    'addr_state',              # state economy affects default rates

    # --- TARGET VARIABLE ---
  
    'loan_status',             
]

print(f"We are loading {len(columns_we_need)} columns")
print("Columns:", columns_we_need)
# Out:
# We are loading 21 columns
# Columns: ['annual_inc', 'emp_length', 'home_ownership', 'verification_status', 'loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'purpose', 'fico_range_low', 'dti', 'delinq_2yrs', 'mths_since_last_delinq', 'pub_rec', 'revol_util', 'open_acc', 'total_acc', 'revol_bal', 'addr_state', 'loan_status']

# %%
print("Loading data in chunks... please wait")
chunks = []

chunk_number = 0

for chunk in pd.read_csv(
    'data/accepted_2007_to_2018Q4.csv',
    usecols=columns_we_need,
    chunksize=50000,
    low_memory=False,
    on_bad_lines='skip'
):
    chunks.append(chunk)
    chunk_number += 1
    print(f"  Loaded chunk {chunk_number} — {chunk_number * 50000:,} rows so far...")

df = pd.concat(chunks, ignore_index=True)
del chunks

print("\n✓ Done!")
print(f"Rows   : {df.shape[0]:,}")
print(f"Columns: {df.shape[1]}")
# Out:
# Loading data in chunks... please wait
#   Loaded chunk 1 — 50,000 rows so far...
#   Loaded chunk 2 — 100,000 rows so far...
#   Loaded chunk 3 — 150,000 rows so far...
#   Loaded chunk 4 — 200,000 rows so far...
#   Loaded chunk 5 — 250,000 rows so far...
#   Loaded chunk 6 — 300,000 rows so far...
#   Loaded chunk 7 — 350,000 rows so far...
#   Loaded chunk 8 — 400,000 rows so far...
#   Loaded chunk 9 — 450,000 rows so far...
#   Loaded chunk 10 — 500,000 rows so far...
#   Loaded chunk 11 — 550,000 rows so far...
#   Loaded chunk 12 — 600,000 rows so far...
#   Loaded chunk 13 — 650,000 rows so far...
#   Loaded chunk 14 — 700,000 rows so far...
#   Loaded chunk 15 — 750,000 rows so far...
#   Loaded chunk 16 — 800,000 rows so far...
#   Loaded chunk 17 — 850,000 rows so far...
#   Loaded chunk 18 — 900,000 rows so far...
#   Loaded chunk 19 — 950,000 rows so far...
#   Loaded chunk 20 — 1,000,000 rows so far...
#   Loaded chunk 21 — 1,050,000 rows so far...
# ...

# %%
# See first 5 rows
print("=== FIRST 5 ROWS ===")
display(df.head())

# See data types of each column
print("\n=== COLUMN DATA TYPES ===")
print(df.dtypes)

# See basic statistics for numeric columns
print("\n=== BASIC STATISTICS ===")
display(df.describe())
# Out:
# === FIRST 5 ROWS ===
#    loan_amnt        term  int_rate  installment grade emp_length  \
# 0     3600.0   36 months     13.99       123.03     C  10+ years
# 1    24700.0   36 months     11.99       820.28     C  10+ years
# 2    20000.0   60 months     10.78       432.66     B  10+ years
# 3    35000.0   60 months     14.85       829.90     C  10+ years
# 4    10400.0   60 months     22.45       289.91     F    3 years
#
#   home_ownership  annual_inc verification_status loan_status  ... addr_state  \
# 0       MORTGAGE     55000.0        Not Verified  Fully Paid  ...         PA
# 1       MORTGAGE     65000.0        Not Verified  Fully Paid  ...         SD
# 2       MORTGAGE     63000.0        Not Verified  Fully Paid  ...         IL
# 3       MORTGAGE    110000.0     Source Verified     Current  ...         NJ
# 4       MORTGAGE    104433.0     Source Verified  Fully Paid  ...         PA
#
#      dti  delinq_2yrs  fico_range_low  mths_since_last_delinq  open_acc  \
# ...
